# %%
# Loading data
import csv
import pandas as pd
import numpy as np
import helper_functions

from tabulate import tabulate

with open("1_13.xls", mode="rb") as file:
        table = pd.read_excel(file,index_col=[0])
table
# Out:
#                         Sustainability     Criteria I  \
# Sustainability Category
# Economy                                   Performance
# Economy                                           NaN
# Economy                                           NaN
# Economy                               Product Quality
# Economy                                           NaN
# Social                                       Exposure
# Social                                            NaN
# Social                                            NaN
# Social                               Work Environment
# Social                                            NaN
# Social                                            NaN
# Ecology                                  Biodiversity
# Ecology                                           NaN
# Ecology                                  Site Quality
# Ecology                                           NaN
# Ecology                                           NaN
# ...

# %%
# or fill with empty
with open("1_13.xls", mode="rb") as file:
        table = pd.read_excel(file).fillna("")

tabulate(table, headers='keys', tablefmt='html', showindex=False)
# Out:
# '<table>\n<thead>\n<tr><th>Sustainability Category  </th><th>Sustainability     Criteria I  </th><th>Sustainability Criteria II             </th><th style="text-align: right;">  Count</th><th>Indicators               </th><th>Unnamed: 5                </th><th>Unnamed: 6            </th><th>Unnamed: 7              </th><th>Unnamed: 8   </th></tr>\n</thead>\n<tbody>\n<tr><td>Economy                  </td><td>Performance                    </td><td>Productivity                           </td><td style="text-align: right;">    123</td><td>[m3/h]                   </td><td>                          </td><td>                      </td><td>                        </td><td>             </td></tr>\n<tr><td>                         </td><td>                               </td><td>Costs                                  </td><td style="text-align: right;">     82</td><td>[Costs/m3]               </td><td>[Costs/h]                 </td><td>                      </td><td>                        <
# ...
